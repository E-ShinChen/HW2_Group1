# %%
from sklearn import metrics
from sklearn.model_selection import  train_test_split
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import *
from keras.preprocessing.image import img_to_array

from keras import layers
from keras import models
from keras.utils import np_utils
from keras.utils import to_categorical
from keras import optimizers
import tensorflow as tf
import keras
from keras.models import Model
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import Input, MaxPooling2D, Dropout, Flatten
from keras import regularizers
from keras.models import load_model, model_from_yaml
from keras.applications.resnet50 import ResNet50
from keras.applications.mobilenet_v2 import MobileNetV2
from keras.applications.vgg19 import VGG19
from keras.applications.vgg16 import VGG16
from keras.applications.inception_v3 import InceptionV3
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import optimizers
from datetime import datetime
import csv
import random
import cv2
import numpy as np
import os
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from tqdm import tqdm
import collections
import os
# Out:
# Using TensorFlow backend.
# C:\Users\user\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\user\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\user\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\user\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\user\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\user\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\user\Anaconda3\envs\tensorflow\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\user\Anaconda3\envs\tensorflow\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\user\Anaconda3\envs\tensorflow\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\user\Anaconda3\envs\tensorflow\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\user\Anaconda3\envs\tensorflow\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\user\Anaconda3\envs\tensorflow\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
allpath=[]
def isdirorfile(basepath):
    with os.scandir(basepath) as entries:
        for entry in entries:
            if entry.is_file():
                a = os.path.join(basepath,entry.name)
                if a not in allpath:
                    allpath.append(os.path.join(basepath,entry.name))
            elif entry.is_dir():
                a=os.listdir(basepath)
                if len(a)>=2:
                    tmp=[]                    
                    for i in a:
                        tmp.append(os.path.join(basepath,i))
                    for addr in tmp:
                        isdirorfile(addr)
                else:
                    return isdirorfile(os.path.join(basepath,str(entry.name)))
def datapath(basepath:str):
    dirs = [i for i in os.listdir(basepath)]
    path = [isdirorfile(os.path.join(basepath,x))for x in dirs]
    print(f'總共資料數{len(allpath)}')
    path = allpath
    return path

# %%
traindata=datapath(basepath='train')
classes = [i for i in os.listdir('train')]
allpath=[]#初始化宮用餐數
testdata=datapath(basepath='test')
classes={classes[n]:n for n,i in enumerate(classes)}
print(classes)
label=[classes[i.split("\\")[-2]] for i in traindata]
label = np.array(to_categorical(label,10))
test_label=[classes[i.split("\\")[-2]] for i in testdata]
test_label = np.array(to_categorical(test_label,10))

image_path = [os.path.join(os.getcwd(),i) for i in traindata]
test_im_path = [os.path.join(os.getcwd(),i) for i in testdata]

im = [cv2.imread(image_path[i]) for i in tqdm(range(len(image_path)))]
im = [np.array(img_to_array(cv2.resize(image,(32,32),interpolation=cv2.INTER_LINEAR))/255.0) for image in tqdm(im)]

test_im = [cv2.imread(test_im_path[i]) for i in tqdm(range(len(test_im_path)))]
test_im = [np.array(img_to_array(cv2.resize(image,(32,32),interpolation=cv2.INTER_LINEAR))/255.0) for image in tqdm(test_im)]
X,val_X,Y,val_Y = train_test_split(np.array(im),np.array(label),test_size=0.2,random_state=8763)
print(X.shape,val_X.shape,Y.shape,val_Y.shape )
# Out:
# 總共資料數50000
#   0%|                                                                                                                                                                  | 0/50000 [00:00<?, ?it/s]
# 總共資料數10000
# {'airplane': 0, 'automobile': 1, 'bird': 2, 'cat': 3, 'deer': 4, 'dog': 5, 'frog': 6, 'horse': 7, 'ship': 8, 'truck': 9}
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50000/50000 [04:07<00:00, 202.08it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50000/50000 [00:00<00:00, 81914.21it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10000/10000 [00:10<00:00, 930.59it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10000/10000 [00:00<00:00, 80215.12it/s]
# (40000, 32, 32, 3) (10000, 32, 32, 3) (40000, 10) (10000, 10)

# %%
def conv2d_bn(x,filters, num_row,num_col,padding='same',strides=(1, 1),name=None):
    x = Conv2D(
        filters, (num_row, num_col),
        strides=strides,
        padding=padding,
        use_bias=False,
        name=name)(x)
    x = layers.BatchNormalization(axis=3, scale=False)(x)
    x = layers.Activation('relu')(x)
    return x
def get_model(w=32,h=32,ch=3):
    inputs = keras.Input((w, h, ch))
    
    x = conv2d_bn(inputs,32,3,3,strides=(2,2))
    x = MaxPooling2D(pool_size=3,strides=1)(x)
    x = conv2d_bn(x,64,3,3)
    x = MaxPooling2D(pool_size=3,strides=2)(x)
    x = conv2d_bn(x,96,3,3)
    x = MaxPooling2D(pool_size=3,strides=1)(x)
    flatten_layer = Flatten()(x)
    dense_layer_1 = Dense(512,activation='relu')(flatten_layer)
    dense_layer_2 = Dense(256,activation='relu')(dense_layer_1)
    outputs = Dense(10,activation='softmax')(dense_layer_2)
    model = keras.Model(inputs,outputs,name="CIFAR10Net")
    return model

# %%
model = get_model(32,32,3)
model.summary()
model.compile(optimizer= keras.optimizers.Adadelta(lr=1.0, rho=0.95, epsilon=1e-08, decay=0.0) , loss='categorical_crossentropy' , metrics=['accuracy'])
early_stopping = EarlyStopping(monitor='val_accuracy', mode = "max",patience=10,restore_best_weights=True)
history = model.fit(
    X,
    y=Y,
    batch_size=32,
    validation_data=(val_X, val_Y),
    epochs=1000,
    shuffle=True,
    verbose=1,
    callbacks=[early_stopping]
)
print("done!")
# Out:
# Model: "CIFAR10Net"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 16, 16, 32)        864
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 16, 16, 32)        96
# _________________________________________________________________
# activation_12 (Activation)   (None, 16, 16, 32)        0
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 14, 14, 64)        18432
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 14, 14, 64)        192
# _________________________________________________________________
# activation_13 (Activation)   (None, 14, 14, 64)        0
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 6, 6, 96)          55296
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 6, 6, 96)          288
# _________________________________________________________________
# activation_14 (Activation)   (None, 6, 6, 96)          0
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 4, 4, 96)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 1536)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               786944
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_9 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 996,010
# Trainable params: 995,626
# Non-trainable params: 384
# _________________________________________________________________
# WARNING:tensorflow:From C:\Users\user\Anaconda3\envs\tensorflow\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1000
# 40000/40000 [==============================] - 8s 189us/step - loss: 1.4195 - accuracy: 0.4865 - val_loss: 1.3834 - val_accuracy: 0.5160
# Epoch 2/1000
# 40000/40000 [==============================] - 7s 165us/step - loss: 1.0679 - accuracy: 0.6194 - val_loss: 1.0717 - val_accuracy: 0.6153
# Epoch 3/1000
# 40000/40000 [==============================] - 7s 165us/step - loss: 0.9139 - accuracy: 0.6795 - val_loss: 1.2857 - val_accuracy: 0.5860
# Epoch 4/1000
# 40000/40000 [==============================] - 7s 166us/step - loss: 0.8106 - accuracy: 0.7128 - val_loss: 1.2425 - val_accuracy: 0.6174
# Epoch 5/1000
# 40000/40000 [==============================] - 7s 166us/step - loss: 0.7364 - accuracy: 0.7397 - val_loss: 0.9945 - val_accuracy: 0.6792
# Epoch 6/1000
# 40000/40000 [==============================] - 7s 165us/step - loss: 0.6690 - accuracy: 0.7629 - val_loss: 0.8839 - val_accuracy: 0.7012
# Epoch 7/1000
# 40000/40000 [==============================] - 7s 166us/step - loss: 0.6131 - accuracy: 0.7839 - val_loss: 0.9352 - val_accuracy: 0.7070
# Epoch 8/1000
# 40000/40000 [==============================] - 7s 165us/step - loss: 0.5593 - accuracy: 0.8023 - val_loss: 0.8055 - val_accuracy: 0.7297
# Epoch 9/1000
# 40000/40000 [==============================] - 7s 165us/step - loss: 0.5147 - accuracy: 0.8180 - val_loss: 1.1235 - val_accuracy: 0.6538
# Epoch 10/1000
# 40000/40000 [==============================] - 7s 165us/step - loss: 0.4734 - accuracy: 0.8319 - val_loss: 0.9445 - val_accuracy: 0.7154
# Epoch 11/1000
# 40000/40000 [==============================] - 7s 165us/step - loss: 0.4318 - accuracy: 0.8469 - val_loss: 0.8565 - val_accuracy: 0.7358
# Epoch 12/1000
# 40000/40000 [==============================] - 7s 165us/step - loss: 0.3932 - accuracy: 0.8585 - val_loss: 0.9259 - val_accuracy: 0.7273
# Epoch 13/1000
# 40000/40000 [==============================] - 7s 166us/step - loss: 0.3653 - accuracy: 0.8714 - val_loss: 0.9693 - val_accuracy: 0.7312
# Epoch 14/1000
# 40000/40000 [==============================] - 7s 166us/step - loss: 0.3274 - accuracy: 0.8845 - val_loss: 0.8779 - val_accuracy: 0.7395
# Epoch 15/1000
# 40000/40000 [==============================] - 7s 168us/step - loss: 0.3011 - accuracy: 0.8950 - val_loss: 1.0084 - val_accuracy: 0.7303
# Epoch 16/1000
# 40000/40000 [==============================] - 7s 166us/step - loss: 0.2730 - accuracy: 0.9037 - val_loss: 1.1485 - val_accuracy: 0.7125
# Epoch 17/1000
# 40000/40000 [==============================] - 7s 167us/step - loss: 0.2459 - accuracy: 0.9124 - val_loss: 1.0680 - val_accuracy: 0.7223
# Epoch 18/1000
# 40000/40000 [==============================] - 7s 166us/step - loss: 0.2219 - accuracy: 0.9217 - val_loss: 1.0226 - val_accuracy: 0.7440
# Epoch 19/1000
# 40000/40000 [==============================] - 7s 166us/step - loss: 0.1980 - accuracy: 0.9295 - val_loss: 1.0466 - val_accuracy: 0.7499
# Epoch 20/1000
# 40000/40000 [==============================] - 7s 165us/step - loss: 0.1823 - accuracy: 0.9359 - val_loss: 1.1659 - val_accuracy: 0.7486
# Epoch 21/1000
# 40000/40000 [==============================] - 7s 166us/step - loss: 0.1664 - accuracy: 0.9423 - val_loss: 1.1644 - val_accuracy: 0.7435
# Epoch 22/1000
# 40000/40000 [==============================] - 7s 165us/step - loss: 0.1518 - accuracy: 0.9462 - val_loss: 1.1772 - val_accuracy: 0.7474
# Epoch 23/1000
# 40000/40000 [==============================] - 7s 166us/step - loss: 0.1375 - accuracy: 0.9511 - val_loss: 1.2934 - val_accuracy: 0.7266
# Epoch 24/1000
# 40000/40000 [==============================] - 7s 165us/step - loss: 0.1286 - accuracy: 0.9552 - val_loss: 1.5958 - val_accuracy: 0.7125
# Epoch 25/1000
# 40000/40000 [==============================] - 7s 166us/step - loss: 0.1160 - accuracy: 0.9585 - val_loss: 1.6077 - val_accuracy: 0.7127
# Epoch 26/1000
# 40000/40000 [==============================] - 7s 166us/step - loss: 0.1081 - accuracy: 0.9621 - val_loss: 1.5001 - val_accuracy: 0.7301
# Epoch 27/1000
# 40000/40000 [==============================] - 7s 166us/step - loss: 0.0972 - accuracy: 0.9661 - val_loss: 1.3041 - val_accuracy: 0.7514
# Epoch 28/1000
# 40000/40000 [==============================] - 7s 167us/step - loss: 0.0939 - accuracy: 0.9670 - val_loss: 1.3454 - val_accuracy: 0.7537
# Epoch 29/1000
# 40000/40000 [==============================] - 7s 166us/step - loss: 0.0883 - accuracy: 0.9695 - val_loss: 1.5405 - val_accuracy: 0.7267
# Epoch 30/1000
# 40000/40000 [==============================] - 7s 167us/step - loss: 0.0813 - accuracy: 0.9725 - val_loss: 1.4927 - val_accuracy: 0.7379
# Epoch 31/1000
# 40000/40000 [==============================] - 7s 166us/step - loss: 0.0763 - accuracy: 0.9735 - val_loss: 1.4356 - val_accuracy: 0.7463
# Epoch 32/1000
# 40000/40000 [==============================] - 7s 166us/step - loss: 0.0676 - accuracy: 0.9769 - val_loss: 1.8418 - val_accuracy: 0.7033
# Epoch 33/1000
# 40000/40000 [==============================] - 7s 166us/step - loss: 0.0676 - accuracy: 0.9775 - val_loss: 1.7586 - val_accuracy: 0.7267
# Epoch 34/1000
# 40000/40000 [==============================] - 7s 166us/step - loss: 0.0637 - accuracy: 0.9790 - val_loss: 1.5535 - val_accuracy: 0.7558
# Epoch 35/1000
# 40000/40000 [==============================] - 7s 167us/step - loss: 0.0625 - accuracy: 0.9792 - val_loss: 1.5387 - val_accuracy: 0.7505
# Epoch 36/1000
# 40000/40000 [==============================] - 7s 165us/step - loss: 0.0608 - accuracy: 0.9793 - val_loss: 1.8974 - val_accuracy: 0.7514
# Epoch 37/1000
# 40000/40000 [==============================] - 7s 165us/step - loss: 0.0553 - accuracy: 0.9814 - val_loss: 1.6399 - val_accuracy: 0.7511
# Epoch 38/1000
# 40000/40000 [==============================] - 7s 166us/step - loss: 0.0564 - accuracy: 0.9808 - val_loss: 2.2663 - val_accuracy: 0.7196
# Epoch 39/1000
# 40000/40000 [==============================] - 7s 166us/step - loss: 0.0511 - accuracy: 0.9822 - val_loss: 1.8750 - val_accuracy: 0.7380
# Epoch 40/1000
# 40000/40000 [==============================] - 7s 167us/step - loss: 0.0504 - accuracy: 0.9832 - val_loss: 1.6782 - val_accuracy: 0.7553
# Epoch 41/1000
# 40000/40000 [==============================] - 7s 166us/step - loss: 0.0456 - accuracy: 0.9852 - val_loss: 1.6435 - val_accuracy: 0.7516
# Epoch 42/1000
# 40000/40000 [==============================] - 7s 166us/step - loss: 0.0474 - accuracy: 0.9842 - val_loss: 2.2130 - val_accuracy: 0.7251
# Epoch 43/1000
# 40000/40000 [==============================] - 7s 166us/step - loss: 0.0433 - accuracy: 0.9854 - val_loss: 1.6897 - val_accuracy: 0.7612
# Epoch 44/1000
# 40000/40000 [==============================] - 7s 165us/step - loss: 0.0433 - accuracy: 0.9859 - val_loss: 1.9686 - val_accuracy: 0.7330
# Epoch 45/1000
# 40000/40000 [==============================] - 7s 166us/step - loss: 0.0438 - accuracy: 0.9857 - val_loss: 1.8392 - val_accuracy: 0.7495
# Epoch 46/1000
# 40000/40000 [==============================] - 7s 166us/step - loss: 0.0426 - accuracy: 0.9857 - val_loss: 1.8973 - val_accuracy: 0.7321
# Epoch 47/1000
# 40000/40000 [==============================] - 7s 166us/step - loss: 0.0430 - accuracy: 0.9863 - val_loss: 2.2498 - val_accuracy: 0.7300
# Epoch 48/1000
# 40000/40000 [==============================] - 7s 166us/step - loss: 0.0408 - accuracy: 0.9865 - val_loss: 2.2535 - val_accuracy: 0.7313
# Epoch 49/1000
# 40000/40000 [==============================] - 7s 166us/step - loss: 0.0394 - accuracy: 0.9872 - val_loss: 1.9092 - val_accuracy: 0.7502
# Epoch 50/1000
# 40000/40000 [==============================] - 7s 166us/step - loss: 0.0371 - accuracy: 0.9872 - val_loss: 1.8187 - val_accuracy: 0.7522
# Epoch 51/1000
# 40000/40000 [==============================] - 7s 166us/step - loss: 0.0383 - accuracy: 0.9876 - val_loss: 2.2336 - val_accuracy: 0.7468
# Epoch 52/1000
# 40000/40000 [==============================] - 7s 167us/step - loss: 0.0393 - accuracy: 0.9878 - val_loss: 2.3361 - val_accuracy: 0.7336
# Epoch 53/1000
# 40000/40000 [==============================] - 7s 166us/step - loss: 0.0348 - accuracy: 0.9887 - val_loss: 2.1495 - val_accuracy: 0.7553

# %%
def plot_loss_accu(history):
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(len(loss))
    plt.plot(epochs, loss, 'r')
    plt.plot(epochs, val_loss, 'b')
    #plt.title('Training and validation loss')
    plt.ylabel('Loss %')
    plt.xlabel('Epoch')
    plt.legend(['train', 'val'], loc='upper right')
    plt.grid(True)
    plt.savefig('{}_loss.jpg'.format("Training and validation loss"), dpi=100)
    #plt.savefig('{}_loss.pdf'.format( EXP_NAME), dpi=300)
    plt.show()
    
    loss = history.history['accuracy']
    val_loss = history.history['val_accuracy']
    epochs = range(len(loss))
    plt.plot(epochs, loss, 'r')
    plt.plot(epochs, val_loss, 'b')
    #plt.title('Training and validation accuracy')
    plt.ylabel('Accuracy %')
    plt.xlabel('Epoch')
    plt.legend(['train', 'val'], loc='lower right')
    plt.grid(True)
    plt.savefig('{}_acc.jpg'.format("Training and validation"), dpi=100)
    #plt.savefig('{}_acc.pdf'.format(output_path, EXP_NAME), dpi=300)
    plt.show()

# %%
from keras.utils import plot_model
plot_model(model, to_file='mangovgg.png')
y_pred_max = []

y_true = [np.argmax(i)for i in test_label]
print(np.array(test_im).shape)
for valdata in (test_im):
    prediction = model.predict(np.expand_dims(valdata, axis=0))[0]
    y_pred_max.append( np.argmax(prediction))
    
plot_loss_accu(history)
# Out:
# (10000, 32, 32, 3)

# %%
from sklearn.metrics import confusion_matrix, classification_report,ConfusionMatrixDisplay
import collections
print(collections.Counter(y_true))
confusion_mtx = confusion_matrix(y_true, y_pred_max)
class_names = [i for i in os.listdir('train')]
disp = ConfusionMatrixDisplay(confusion_matrix=confusion_mtx,display_labels=class_names)
disp.plot()

print(classification_report(y_true, y_pred_max, target_names=class_names))
# Out:
# Counter({0: 1000, 1: 1000, 2: 1000, 3: 1000, 4: 1000, 5: 1000, 6: 1000, 7: 1000, 8: 1000, 9: 1000})
#               precision    recall  f1-score   support
#
#     airplane       0.75      0.81      0.78      1000
#   automobile       0.84      0.89      0.86      1000
#         bird       0.72      0.63      0.67      1000
#          cat       0.57      0.59      0.58      1000
#         deer       0.70      0.75      0.73      1000
#          dog       0.72      0.59      0.65      1000
#         frog       0.83      0.79      0.81      1000
#        horse       0.73      0.83      0.78      1000
#         ship       0.81      0.86      0.84      1000
#        truck       0.87      0.78      0.82      1000
#
#     accuracy                           0.75     10000
#    macro avg       0.75      0.75      0.75     10000
# weighted avg       0.75      0.75      0.75     10000
