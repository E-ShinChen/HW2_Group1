# %%
import os
import pandas as pd
import shutil

# %%
label = pd.read_csv('./dataset/Mango/DATA/train.csv')

# %%
label
# Out:
#        image_id label
# 0     00002.jpg     C
# 1     00003.jpg     C
# 2     00004.jpg     B
# 3     00005.jpg     A
# 4     00007.jpg     A
# ...         ...   ...
# 6125  07681.jpg     B
# 6126  07682.jpg     C
# 6127  07683.jpg     A
# 6128  07684.jpg     C
# 6129  07685.jpg     A
#
# [6130 rows x 2 columns]

# %%
for i in range(len(label)):
    img, la = label.iloc[i,:]
    shutil.copyfile('./dataset/Mango/DATA/Train_Image/' + str(img), './dataset/Mango/DATA/Train/' + str(la) + '/' + str(img))
    print('img-------' + str(img))
    print('label-----' + str(la))
# Out:
# img-------00002.jpg
# label-----C
# img-------00003.jpg
# label-----C
# img-------00004.jpg
# label-----B
# img-------00005.jpg
# label-----A
# img-------00007.jpg
# label-----A
# img-------00008.jpg
# label-----B
# img-------00009.jpg
# label-----B
# img-------00010.jpg
# label-----A
# img-------00012.jpg
# label-----A
# img-------00013.jpg
# label-----B
# img-------00014.jpg
# label-----A
# img-------00015.jpg
# label-----A
# img-------00017.jpg
# label-----A
# img-------00018.jpg
# label-----A
# img-------00019.jpg
# label-----A
# img-------00020.jpg
# label-----B
# img-------00021.jpg
# label-----C
# img-------00022.jpg
# label-----C
# img-------00023.jpg
# label-----B
# img-------00024.jpg
# label-----C
# img-------00026.jpg
# label-----B
# img-------00027.jpg
# label-----B
# img-------00029.jpg
# label-----C
# img-------00030.jpg
# label-----A
# img-------00031.jpg
# label-----B
# img-------00032.jpg
# label-----B
# img-------00033.jpg
# label-----A
# img-------00036.jpg
# ...

# %%
la = label.loc[label['image_id']=='00002.jpg']['label']

# %%
print(str(la[0]))
# Out:
# C
